# %%
import requests
from parsel import Selector
import js2xml

# %%
url = 'http://huaban.com/favorite/beauty/'

# %%
params = {
    'max':'',
    'limit':'101',
}

# %%
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
}

# %%
z = requests.get(url=url,params=params,headers=headers)

# %%
z.status_code
# Out:
# 200

# %%
z.url
# Out:
# u'http://huaban.com/favorite/beauty/?max=1093904637&limit=20&j1an6is5=&wfl=1'

# %%
z.text
# Out:
# u'<!DOCTYPE html><html lang="zh"> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/> <meta name="copyright" content="huaban.com"/> <meta name="referrer" content="always"/> <title>\u82b1\u74e3</title> <link rel="apple-touch-icon" href="/img/touch-icon-iphone.png"/> <link rel="apple-touch-icon" sizes="76x76" href="/img/touch-icon-ipad.png"/> <link rel="apple-touch-icon" sizes="120x120" href="/img/touch-icon-iphone-retina.png"/> <link rel="apple-touch-icon" sizes="152x152" href="/img/touch-icon-ipad-retina.png"/>  <link rel="canonical" href="http://huaban.com/favorite/beauty/"/>    <meta name="keywords" content="\u5bb6\u5c45\u3001\u65c5\u884c\u3001\u7f8e\u98df\u3001\u9020\u578b&#47;\u5986\u53d1\u3001\u6444\u5f71\u3001\u670d\u9970&#47;\u642d\u914d&#47;\u8857\u62cd\u3001\u7ae5\u771f\u3001\u5a5a\u7eb1&#47;\u5a5a\u793c\u3001\u5ba0\u7269\u3001\u624b\u5de5&#47;\u5e03\u827a&#47;\u73a9\u7269\u3001\u5efa\u7b51\u3001\u521b\u610f&#47;\u8bbe\u8ba1\u3001\u4
# ...

# %%
headers['Accept'] = 'application/json'

# %%
headers
# Out:
# {'Accept': 'application/json',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}

# %%
z1 = requests.get(url=url,params=params,headers=headers)

# %%
z1.text
# Out:
# u'<!DOCTYPE html><html lang="zh"> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/> <meta name="copyright" content="huaban.com"/> <meta name="referrer" content="always"/> <title>\u82b1\u74e3</title> <link rel="apple-touch-icon" href="/img/touch-icon-iphone.png"/> <link rel="apple-touch-icon" sizes="76x76" href="/img/touch-icon-ipad.png"/> <link rel="apple-touch-icon" sizes="120x120" href="/img/touch-icon-iphone-retina.png"/> <link rel="apple-touch-icon" sizes="152x152" href="/img/touch-icon-ipad-retina.png"/>  <link rel="canonical" href="http://huaban.com/favorite/beauty/"/>    <meta name="keywords" content="\u5bb6\u5c45\u3001\u65c5\u884c\u3001\u7f8e\u98df\u3001\u9020\u578b&#47;\u5986\u53d1\u3001\u6444\u5f71\u3001\u670d\u9970&#47;\u642d\u914d&#47;\u8857\u62cd\u3001\u7ae5\u771f\u3001\u5a5a\u7eb1&#47;\u5a5a\u793c\u3001\u5ba0\u7269\u3001\u624b\u5de5&#47;\u5e03\u827a&#47;\u73a9\u7269\u3001\u5efa\u7b51\u3001\u521b\u610f&#47;\u8bbe\u8ba1\u3001\u4
# ...

# %%
headers['X-Request'] = 'JSON'
headers['X-Requested-With'] = 'XMLHttpRequest'

# %%
z2 = requests.get(url=url,params=params,headers=headers)

# %%
z2.json()
# Out:
# {u'banner_box_promotion': None,
#  u'explore': None,
#  u'filter': u'pin:category:beauty',
#  u'pins': [{u'board': {u'board_id': 16420745,
#     u'category_id': u'beauty',
#     u'created_at': 1405395857,
#     u'deleting': 0,
#     u'description': u'\u65f6\u5149-\u96d5\u523b\u4e0b\u6700\u7cbe\u81f4\u7684\u77ac\u95f4',
#     u'extra': None,
#     u'follow_count': 1621,
#     u'is_private': 0,
#     u'like_count': 21,
#     u'pin_count': 1037,
#     u'seq': 4,
#     u'title': u'S-pretty',
#     u'updated_at': 1491698516,
#     u'user_id': 6545006},
#    u'board_id': 16420745,
#    u'comment_count': 0,
#    u'created_at': 1491698516,
#    u'file': {u'bucket': u'hbimg',
#     u'colors': [{u'color': 5723991, u'ratio': 0.1},
#      {u'color': 6710886, u'ratio': 0.1}],
#     u'farm': u'farm1',
#     u'frames': u'1',
#     u'height': u'965',
#     u'id': 114864524,
#     u'key': u'429f645bd430a700bd997af8aecd819d8dc9fb082fd07-Xxw4bC',
#     u'theme': u'575757',
# ...

# %%
ll = z2.json()

# %%
len(ll['pins'])
# Out:
# 20

# %%
ll['pins'][0]['pin_id']
# Out:
# 1093888536

# %%
for i in ll['pins']:
    print i['pin_id']
# Out:
# 1093888536
# 1093875533
# 1093704297
# 1093883468
# 1093789374
# 1093857940
# 1093781100
# 1093731343
# 1093875507
# 1093657938
# 1093875593
# 1093888207
# 1093791788
# 1093789316
# 1093787188
# 1093686011
# 1093704134
# 1093789508
# 1093697491
# 1093657651

# %%
ll['pins'][-1]['pin_id']
# Out:
# 1093657651

# %%
z3 = requests.get(url=url,params=params,headers=headers)

# %%
len(z3.json()['pins'])
# Out:
# 100

# %%
z4 = requests.get(url=url,params=params,headers=headers)

# %%
len(z4.json()['pins'])
# Out:
# 100

# %%
detailurl = 'http://huaban.com/pins/1094436033/'

# %%
z5 = requests.get(url,headers=headers)

# %%
z5.status_code
# Out:
# 200

# %%
z5.json()
# Out:
# {u'ads': {u'fixedAds': [], u'normalAds': []},
#  u'banner_box_promotion': None,
#  u'boards': [{u'board_id': 30377705,
#    u'category_id': u'beauty',
#    u'created_at': 1466594533,
#    u'deleting': 0,
#    u'description': u'\u6b64\u60c5\u53ef\u5f85\u6210\u8ffd\u5fc6\uff0c\u53ea\u662f\u5f53\u65f6\u5df2\u60d8\u7136\u3002 \uff0d\u674e\u5546\u9690\u300a\u9526\u745f\u300b\n\u5317\u65b9\u6709\u4f73\u4eba\uff0c\u7edd\u4e16\u800c\u72ec\u7acb\u3002\u4e00\u987e\u503e\u4eba\u57ce\uff0c\u518d\u987e\u503e\u4eba\u56fd\u3002\u5b81\u4e0d\u77e5\u503e\u57ce\u4e0e\u503e\u56fd\uff0c\u4f73\u4eba\u96be\u518d\u5f97\uff01\uff0d\u674e\u5ef6\u5e74\u300a\u4f73\u4eba\u6b4c\u300b',
#    u'extra': None,
#    u'follow_count': 1195,
#    u'is_private': 0,
#    u'like_count': 55,
#    u'pin_count': 4028,
#    u'pins': [{u'board_id': 30377705,
#      u'comment_count': 0,
#      u'created_at': 1487558919,
#      u'file': {u'bucket': u'hbimg',
#       u'frames': u'1',
#       u'height': u'1034',
# ...

# %%
for i in z5.json()['pins']:
    print i['file']['key']
# Out:
# 344c56cc253d8a3b69688d81e6573d9df972c64f2c46d-k4LQWr
# 57a7a326b16e4b65d133edd9bf6dff2cb62a7cd34f83f-lBSorx
# 22d29cf5683c6170af92efa22a0c0ce9c37dd93e5a9fc-Q1ZO1Y
# 1f45a3723c325fce4d73f6fe6ab4c311920949af7752b-UDWRFH
# fc68b36ecd56ecf9e8eab9665bde9cd27345a313c952-tmGCcR
# 120e787c8520b32f44d90175e7074b88cffb9aa12784b-gQElXN
# eaf88d64a7b13a82936e58194220af24be1bc3173878d-lCUb0y
# 32b2c8261bd093906cc02f7dd461d11c651b36c0681dc-Sb3Zqd
# 029f8e413d30181a7ac249439b483e7c24a8fd1a44904-2fVkPy
# f01942958d13852c938c0766613a3b482ef8f8432570f-9g7TJ6
# 3178dde022e8692a5d2b1152fae1f977b92e49a124179-6WkbFx
# 4479992344e4d74c5e524194802615fd853e7c3ef1efc-1AVSAo
# 2df187d1adf48728b0a0505521f8e137ef0964b32f422-Wb2CA2
# 0269a5eae7c07b96d70ce8a6441a14e73f9987ef63ece-oxCr0h
# 2c8f913502e996ba73c880987d12eb2a7efa503d1c432-fNDM4k
# cf2cd532947a8c1db3e2326b408f5cbcd8795d0916b0e-XtpbNb
# 6e67799083da8cf181af7f005cb73f28dae0309217476-EuSYB7
# 4e77c159c60561558c48351a5323395680e43e162f2bc-ws0zSU
# ...

# %%
headers
# Out:
# {'Accept': 'application/json',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
#  'X-Request': 'JSON',
#  'X-Requested-With': 'XMLHttpRequest'}

# %%
headers1 = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
}

# %%
z5 = requests.get(url,headers=headers1)

# %%
z5.text
# Out:
# u'<!DOCTYPE html><html lang="zh"> <head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/> <meta name="copyright" content="huaban.com"/> <meta name="referrer" content="always"/> <title>\u7f8e\u5973_\u82b1\u74e3\uff0c\u966a\u4f60\u505a\u751f\u6d3b\u7684\u8bbe\u8ba1\u5e08\uff08\u53d1\u73b0\u3001\u91c7\u96c6\u4f60\u559c\u6b22\u7684\u7f8e\u5973\u56fe\u7247\uff09_\u82b1\u74e3\u7f51</title> <link rel="apple-touch-icon" href="/img/touch-icon-iphone.png"/> <link rel="apple-touch-icon" sizes="76x76" href="/img/touch-icon-ipad.png"/> <link rel="apple-touch-icon" sizes="120x120" href="/img/touch-icon-iphone-retina.png"/> <link rel="apple-touch-icon" sizes="152x152" href="/img/touch-icon-ipad-retina.png"/>  <link rel="canonical" href="http://huaban.com/favorite/beauty/"/>    <meta name="keywords" content="\u7f8e\u5973,\u7f8e\u5973\u56fe\u7247"/> <meta name="description" content="\u82b1\u74e3\u7f51\uff0c\u53d1\u73b0\u91c7\u96c6\u4f60\u559c\u6b22\u7684\u7f8e\u5
# ...

# %%
sel = Selector(text=z5.text)

# %%
sel.xpath('//div[@id="baidu_image_holder"]/img/@src')
# Out:
# []

# %%
jscode = sel.xpath("//script[contains(., 'app.page = app.page')]/text()").extract_first()

# %%
parsed_js  = js2xml.parse(jscode)

# %%
print js2xml.pretty_print(parsed_js)
# Out:
# <program>
#   <var name="app">
#     <binaryoperation operation="||">
#       <left>
#         <identifier name="app"/>
#       </left>
#       <right>
#         <object/>
#       </right>
#     </binaryoperation>
#   </var>
#   <assign operator="=">
#     <left>
#       <dotaccessor>
#         <object>
#           <identifier name="app"/>
#         </object>
#         <property>
#           <identifier name="page"/>
#         </property>
#       </dotaccessor>
#     </left>
#     <right>
#       <binaryoperation operation="||">
#         <left>
#           <dotaccessor>
#             <object>
#               <identifier name="app"/>
#             </object>
#             <property>
#               <identifier name="page"/>
#             </property>
#           </dotaccessor>
#         </left>
#         <right>
#           <object/>
#         </right>
#       </binaryoperation>
#     </right>
#   </assign>
#   <assign operator="=">
#     <left>
#       <bracketaccessor>
# ...

# %%
for i in parsed_js.xpath('//property[@name="key"]/string/text()'):
    print 'http://img.hb.aicdn.com/' + i
# Out:
# http://img.hb.aicdn.com/00ac7d5d1372dca060013884a917268631a9e11128fce-nfWTpi
# http://img.hb.aicdn.com/f5ae8914907574e954466bc814d196b4330095d317d9b3-No1CTj
# http://img.hb.aicdn.com/8d4030d7092d0367ff606cb944286908a6c5c536318a94-kKLETw
# http://img.hb.aicdn.com/893095cb0e53676bc4e5035f4868fe192c0897fd2889b-mbUjxt
# http://img.hb.aicdn.com/d623b6128c7611377d6c1ed3241d3769c091749f8a914-fNM0gq
# http://img.hb.aicdn.com/ecee63929409612d06d5c22c6fa7dabe42eb470826db-GyN3kP
# http://img.hb.aicdn.com/9d1b1729495c1dc71a27b73e15fe3a00d2b1f66e524f-oYkBsb
# http://img.hb.aicdn.com/629f7ffb97ff75f005927188314735f73dcf93e3147b5-bW1j9s
# http://img.hb.aicdn.com/5bbafd804c646b4062af163c349af60cb8a9831627ba6-83vI5S
# http://img.hb.aicdn.com/3fb4b4816707f190a9e2227757102dd8407d3c611f585-UypiaW
# http://img.hb.aicdn.com/65be0ac845554f0a63600862004c5e7aa2f81a3abe9f0-VqcXZv
# http://img.hb.aicdn.com/f56166cc72c040ad73574366a26cd15f2f4268b734c18-yVcNOl
# ...

# %%
len(parsed_js.xpath('//property[@name="key"]/string/text()'))
# Out:
# 120

# %%
url1 = 'http://huaban.com/pins/1094436033/'

# %%
z6 = requests.get(url1,headers=headers1)

# %%
sel1 = Selector(text=z6.text)

# %%
jscode1 = sel1.xpath("//script[contains(., 'app.page = app.page')]/text()").extract_first()

# %%
jscode1
# Out:
# u' var app = app || {};\napp.page = app.page || {};\napp.page["$url"] = "/pins/1094436033/";\napp.page["pin"] = {"pin_id":1094436033, "user_id":20542706, "board_id":35719862, "file_id":135008944, "file":{"id":135008944, "farm":"farm1", "bucket":"hbimg", "key":"831c430bd729cd0b739e3fd188de0a82b887cbd92312c9-enIzxv", "type":"image/jpeg", "width":"1680", "height":"2539", "frames":"1", "colors":[{"color":2829099, "ratio":0.16}, {"color":11447982, "ratio":0.09}], "audit":{"porn":{"rate":0.9954113797284663, "label":0, "review":false}}, "theme":"2b2b2b"}, "media_type":0, "source":null, "link":"", "raw_text":" ", "text_meta":{}, "via":1081834192, "via_user_id":17949009, "original":1081202106, "created_at":1491742920, "like_count":0, "comment_count":0, "repin_count":0, "is_private":0, "orig_source":null, "user":{"user_id":20542706, "username":"\u866b\u4e8c1234", "urlname":"kimgao1995", "created_at":1491742900, "avatar":{"id":136226279, "farm":"farm1", "bucket":"hbimg", "key":"70f876d06fbd4699
# ...

# %%
parsed_js  = js2xml.parse(jscode1)

# %%
print js2xml.pretty_print(parsed_js)
# Out:
# <program>
#   <var name="app">
#     <binaryoperation operation="||">
#       <left>
#         <identifier name="app"/>
#       </left>
#       <right>
#         <object/>
#       </right>
#     </binaryoperation>
#   </var>
#   <assign operator="=">
#     <left>
#       <dotaccessor>
#         <object>
#           <identifier name="app"/>
#         </object>
#         <property>
#           <identifier name="page"/>
#         </property>
#       </dotaccessor>
#     </left>
#     <right>
#       <binaryoperation operation="||">
#         <left>
#           <dotaccessor>
#             <object>
#               <identifier name="app"/>
#             </object>
#             <property>
#               <identifier name="page"/>
#             </property>
#           </dotaccessor>
#         </left>
#         <right>
#           <object/>
#         </right>
#       </binaryoperation>
#     </right>
#   </assign>
#   <assign operator="=">
#     <left>
#       <bracketaccessor>
# ...

# %%
for i in parsed_js.xpath('//property[@name="pins"]//property[@name="key"]/string/text()'):
    print 'http://img.hb.aicdn.com/' + i
# Out:
# http://img.hb.aicdn.com/70c2039b6492a3140fe3ef9a9ff98bdbab3a9b0f47f14-yP20CC
# http://img.hb.aicdn.com/42c30e371150de203a3b61bf3b23b61225c5b89420424-MaxOex
# http://img.hb.aicdn.com/0dedb1164bc0e19ea2b877f1cad5c3a5181d4633ecbe-YMmLIw
# http://img.hb.aicdn.com/831c430bd729cd0b739e3fd188de0a82b887cbd92312c9-enIzxv

# %%
allimg = []

# %%
set(allimg)
# Out:
# {'http://img.hb.aicdn.com/0dedb1164bc0e19ea2b877f1cad5c3a5181d4633ecbe-YMmLIw',
#  'http://img.hb.aicdn.com/16ec006e695b701214d1e88fd0452b54db69ca3b1033f-dEn0sS',
#  'http://img.hb.aicdn.com/35e7070158c28562c270b9868ee8c4705dd1dbd931606-m6V3Ri',
#  'http://img.hb.aicdn.com/42c30e371150de203a3b61bf3b23b61225c5b89420424-MaxOex',
#  'http://img.hb.aicdn.com/70c2039b6492a3140fe3ef9a9ff98bdbab3a9b0f47f14-yP20CC',
#  'http://img.hb.aicdn.com/70f876d06fbd4699186838ebbfbaacfaa578815317f1-4FNiT2',
#  'http://img.hb.aicdn.com/831c430bd729cd0b739e3fd188de0a82b887cbd92312c9-enIzxv'}
